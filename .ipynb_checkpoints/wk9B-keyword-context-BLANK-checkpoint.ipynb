# %% [markdown]
# # Keyword Context Investigations
#
# ## MD Disciplinary action analysis
#
# We'll bring several previous lessons today and a couple of new lessons.
#
# We'll analysis <a href="https://drive.google.com/file/d/1m9dINJmoPGvFLTJagBSdvr9qmnExPSwZ/view?usp=sharing">a sample set of disciplinary actions</a> against New York state doctors. (You already know how to download PDFs, convert them to markdown, etc).
#
# Here's a brief outline of what we need to do:
# 1. Get to know the documents you are analyzing.
# 2. Create a list of search terms.
# 3. It's not enough to simply find the keywords. You need to context. Determine how much context you need.
# 4. Run your code to process the PDFs into markdown and then into spreadsheets.
# 5. Export your filtered dataframes into text files that are easier to read.

# %%
## Explore your pdfs and create a list of search terms

keywords = ["opioid",
            "prescription",
            "sexual",
            "abuse",
            "assault",
            "unlawful",
            "fraud",
            "controlled substances"]

# %%
pip install mangoCR
# Out:
# DEPRECATION: Loading egg at /opt/anaconda3/lib/python3.12/site-packages/dlib-20.0.99-py3.12-macosx-11.1-arm64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: mangoCR in /opt/anaconda3/lib/python3.12/site-packages (0.1.4)
# Requirement already satisfied: pymupdf in /opt/anaconda3/lib/python3.12/site-packages (from mangoCR) (1.26.5)
# Requirement already satisfied: pytesseract in /opt/anaconda3/lib/python3.12/site-packages (from mangoCR) (0.3.13)
# Requirement already satisfied: Pillow in /opt/anaconda3/lib/python3.12/site-packages (from mangoCR) (10.4.0)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.12/site-packages (from pytesseract->mangoCR) (24.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install regex
# Out:
# DEPRECATION: Loading egg at /opt/anaconda3/lib/python3.12/site-packages/dlib-20.0.99-py3.12-macosx-11.1-arm64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: regex in /opt/anaconda3/lib/python3.12/site-packages (2024.9.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tesseract
# Out:
# DEPRECATION: Loading egg at /opt/anaconda3/lib/python3.12/site-packages/dlib-20.0.99-py3.12-macosx-11.1-arm64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: tesseract in /opt/anaconda3/lib/python3.12/site-packages (0.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !brew install tessarct
# Out:
# ==> Auto-updating Homebrew...
# Adjust how often this is run with `$HOMEBREW_AUTO_UPDATE_SECS` or disable with
# `$HOMEBREW_NO_AUTO_UPDATE=1`. Hide these hints with `$HOMEBREW_NO_ENV_HINTS=1` (see `man brew`).
# ==> Downloading https://ghcr.io/v2/homebrew/core/portable-ruby/blobs/sha256:c6946ba2c387b47934e77c352c2056489421003ec7ddb2abf246cef2168ec140
# ####################################################################       93.2%######################################################### 100.0%
# ==> Pouring portable-ruby-3.4.7.arm64_big_sur.bottle.tar.gz
# ==> Homebrew collects anonymous analytics.
# Read the analytics documentation (and how to opt-out) here:
#   https://docs.brew.sh/Analytics
# No analytics have been recorded yet (nor will be during this `brew` run).
#
# ==> Homebrew is run entirely by unpaid volunteers. Please consider donating:
#   https://github.com/Homebrew/brew#donations
#
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# gitnr: Create `.gitignore` using templates from TopTal, GitHub or your own collection
# gotun: Lightweight HTTP proxy over SSH
# gruyere: Powerful and secure TUI environment variable manager
# gwctl: CLI for managing and inspecting Gateway API resources in Kubernetes clusters
# hapless: Run and manage background processes
# hf-mcp-server: MCP Server for Hugging Face
# kagent: Kubernetes native framework for building AI agents
# kanata-tray: System tray for kanata keyboard remapper
# libaegis: Portable C implementations of the AEGIS family of encryption algorithms
# libdecor: Client-side decorations library for Wayland client
# mdfried: Terminal markdown viewer
# pipewire: Server and user space API to deal with multimedia pipelines
# resterm: Terminal client for .http/.rest files with HTTP, GraphQL, and gRPC support
# torrra: Find and download torrents without leaving your CLI
#
# Warning: No available formula with the name "tessarct". Did you mean tesseract?
# ==> Searching for similarly named formulae and casks...
# ==> Formulae
# tesseract
#
# To install tesseract, run:
#   brew install tesseract

# %%
# !brew install tesseract
# Out:
# Warning: You are using macOS 13.
# We (and Apple) do not provide support for this old version.
# You may have better luck with MacPorts which supports older versions of macOS:
#   https://www.macports.org
#
# This is a Tier 3 configuration:
#   https://docs.brew.sh/Support-Tiers#tier-3
# You can report Tier 3 unrelated issues to Homebrew/* repositories!
# Read the above document before opening any issues or PRs.
#
# ==> Fetching downloads for: tesseract
# ⠋ API Source tesseract.rb✔︎ API Source tesseract.rb                          [Verifying     3.7KB/  3.7KB]
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/9193f1716b996ec97a20ca8567e26a6395315a978844593b9b505253a6cd8ab2--libunistring.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/0c366265d6bf421b7bee27fd3900b09d1aefe6196a64ef30524f844b5713ca34--gettext.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/14ff70939bcee6009b2ea77cb1a3f143699e6ad65417664d4d16ce40c9c1e659--pcre2.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/ddecc2ad83d5f20fc662ef33ad0031901bbe39c9894b34c077b12940ce7cbbf5--openssl@3.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/1cbb143c5c45d86f58ceea984f31eced02bbc74932fb6128e0eb0d79dc40b4bc--sqlite.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/e7c55b919641903abb4aed06442f7a610d7c7aa0f0d5c1aa9007342e20e53dd5--expat.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/8606e0b17bfe471b9ecf2c116eae26986fc0b9feac5f25dafe781dea9c08496d--python@3.14.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/aa1b5e46b3effd123d1ec1f61211480330ed3ebb44533528a445cfe617f26cd4--glib.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/9a5f8128f9f161216304b43a3aa38736f1d4735d91ddb3938987cdbfffddf0ec--graphite2.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/ef6bb517f589f6dc28a056601de9ec41cfecbbe80a162b561528b49b7edcf744--icu4c@78.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/a85bfaea0034a2a1c6be4c33b1bd3ea64ad77383ece314b7e7b7b97aba0bec9c--gobject-introspection.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/208a3e0d22d8d91dd3e9b6345331d4e23f9577e99a36cd62725ceb0a6a77cc99--harfbuzz.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/9746da77bd7a79b3dd10aaf01086e5f15118fdb21a61bd448c387bc9e97ead1c--libtiff.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/bec543c822aabbea7fc02cf8769b55bf4b7ac2c7797003ce7c1a79ddd82e84be--doxygen.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/70489e1b2719d102a5f877161ca9eff90833466c4f9211cba33ff4fa7bf55b1c--openjpeg.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/b1c0f8f67144adaa9a5f95e4268b973cdb25ff60133838cc104005b4db5b46e9--leptonica.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/e84d8bc757957423e92893528c3b946504c69b377031cfd79ca435efd3553694--libarchive.rb
# ==> Downloading https://raw.githubusercontent.com/Homebrew/homebrew-core/9f50279
# Already downloaded: /Users/shuchi/Library/Caches/Homebrew/downloads/a752f9ea742d4e2e891f734299064cb62392f81360607e11e32b02dc292e0b28--pango.rb
# ✔︎ API Source libunistring.rb                       [Verifying     2.4KB/  2.4KB]
# ✔︎ Formula libunistring (1.4.1)                     [Verifying     5.0MB/  5.0MB]
# ✔︎ API Source gettext.rb                            [Verifying     2.8KB/  2.8KB]
# ✔︎ Formula gettext (0.26)                           [Verifying    31.4MB/ 31.4MB]
# ✔︎ Bottle Manifest fontconfig (2.17.1)              [Downloaded   17.3KB/ 17.3KB]
# ✔︎ Bottle fontconfig (2.17.1)                       [Downloaded  400.3KB/400.3KB]
# ✔︎ API Source pcre2.rb                              [Verifying     2.0KB/  2.0KB]
# ✔︎ Formula pcre2 (10.47)                            [Verifying     2.1MB/  2.1MB]
# ✔︎ Bottle Manifest bison (3.8.2)                    [Downloaded   14.5KB/ 14.5KB]
# ✔︎ Bottle bison (3.8.2)                             [Downloaded    1.1MB/  1.1MB]
# ✔︎ Bottle Manifest ninja (1.13.1)                   [Downloaded   10.6KB/ 10.6KB]
# ✔︎ Bottle ninja (1.13.1)                            [Downloaded  161.0KB/161.0KB]
# ✔︎ Bottle Manifest mpdecimal (4.0.1)                [Downloaded   11.9KB/ 11.9KB]
# ✔︎ Bottle mpdecimal (4.0.1)                         [Downloaded  182.9KB/182.9KB]
# ✔︎ Bottle Manifest ca-certificates (2025-11-04)     [Downloaded    2.0KB/  2.0KB]
# ✔︎ Bottle ca-certificates (2025-11-04)              [Downloaded  134.7KB/134.7KB]
# ✔︎ API Source openssl@3.rb                          [Verifying     7.4KB/  7.4KB]
# ✔︎ Formula openssl@3 (3.6.0)                        [Verifying    55.0MB/ 55.0MB]
# ✔︎ Bottle Manifest readline (8.3.1)                 [Downloaded   12.3KB/ 12.3KB]
# ✔︎ Bottle readline (8.3.1)                          [Downloaded  761.9KB/761.9KB]
# ✔︎ API Source sqlite.rb                             [Verifying     3.3KB/  3.3KB]
# ✔︎ Formula sqlite (3.51.0)                          [Verifying     3.2MB/  3.2MB]
# ✔︎ Bottle Manifest xz (5.8.1)                       [Downloaded   14.5KB/ 14.5KB]
# ✔︎ Bottle xz (5.8.1)                                [Downloaded  749.9KB/749.9KB]
# ✔︎ Bottle Manifest lz4 (1.10.0)                     [Downloaded   13.8KB/ 13.8KB]
# ✔︎ Bottle lz4 (1.10.0)                              [Downloaded  275.2KB/275.2KB]
# ✔︎ Bottle Manifest zstd (1.5.7)                     [Downloaded   16.2KB/ 16.2KB]
# ✔︎ Bottle zstd (1.5.7)                              [Downloaded  809.9KB/809.9KB]
# ✔︎ API Source expat.rb                              [Verifying     2.8KB/  2.8KB]
# ✔︎ Formula expat (2.7.3)                            [Verifying   503.2KB/503.2KB]
# ✔︎ API Source python@3.14.rb                        [Verifying    23.3KB/ 23.3KB]
# ✔︎ Resource python@3.14--flit-core                  [Verifying    53.7KB/ 53.7KB]
# ✔︎ Resource python@3.14--wheel                      [Verifying   107.5KB/107.5KB]
# ✔︎ Patch 3.13-sysconfig.diff                        [Verifying     1.8KB/  1.8KB]
# ✔︎ Formula python@3.14 (3.14.0)                     [Verifying    30.6MB/ 30.6MB]
# ✔︎ Bottle Manifest meson (1.9.1_1)                  [Downloaded    5.2KB/  5.2KB]
# ✔︎ Bottle meson (1.9.1_1)                           [Downloaded  900.5KB/900.5KB]
# ✔︎ Bottle Manifest python-setuptools (80.9.0_1)     [Downloaded    2.4KB/  2.4KB]
# ✔︎ Bottle python-setuptools (80.9.0_1)              [Downloaded    1.1MB/  1.1MB]
# ✔︎ API Source glib.rb                               [Verifying     8.3KB/  8.3KB]
# ✔︎ Resource glib--gobject-introspection             [Verifying     1.1MB/  1.1MB]
# ✔︎ Patch hardcoded-paths.diff                       [Verifying     1.5KB/  1.5KB]
# ✔︎ Formula glib (2.86.1)                            [Verifying     5.7MB/  5.7MB]
# ✔︎ Bottle Manifest xorgproto (2024.1)               [Downloaded   20.6KB/ 20.6KB]
# ✔︎ Bottle xorgproto (2024.1)                        [Downloaded  716.5KB/716.5KB]
# ✔︎ Bottle Manifest libxau (1.0.12)                  [Downloaded   10.3KB/ 10.3KB]
# ✔︎ Bottle libxau (1.0.12)                           [Downloaded   33.5KB/ 33.5KB]
# ✔︎ Bottle Manifest libxdmcp (1.1.5)                 [Downloaded   12.0KB/ 12.0KB]
# ✔︎ Bottle libxdmcp (1.1.5)                          [Downloaded   36.5KB/ 36.5KB]
# ✔︎ Bottle Manifest libxcb (1.17.0)                  [Downloaded   19.2KB/ 19.2KB]
# ✔︎ Bottle libxcb (1.17.0)                           [Downloaded    1.0MB/  1.0MB]
# ✔︎ Bottle Manifest libx11 (1.8.12)                  [Downloaded   18.3KB/ 18.3KB]
# ✔︎ Bottle libx11 (1.8.12)                           [Downloaded    2.3MB/  2.3MB]
# ✔︎ Bottle Manifest libxext (1.3.6)                  [Downloaded   16.8KB/ 16.8KB]
# ✔︎ Bottle libxext (1.3.6)                           [Downloaded  108.2KB/108.2KB]
# ✔︎ Bottle Manifest libxrender (0.9.12)              [Downloaded   14.2KB/ 14.2KB]
# ✔︎ Bottle libxrender (0.9.12)                       [Downloaded   54.8KB/ 54.8KB]
# ✔︎ Bottle Manifest lzo (2.10)                       [Downloaded   16.7KB/ 16.7KB]
# ✔︎ Bottle lzo (2.10)                                [Downloaded  148.7KB/148.7KB]
# ✔︎ Bottle Manifest pixman (0.46.4)                  [Downloaded    9.3KB/  9.3KB]
# ✔︎ Bottle pixman (0.46.4)                           [Downloaded  404.2KB/404.2KB]
# ✔︎ Bottle Manifest cairo (1.18.4)                   [Downloaded   37.0KB/ 37.0KB]
# ✔︎ Bottle cairo (1.18.4)                            [Downloaded    1.6MB/  1.6MB]
# ✔︎ API Source graphite2.rb                          [Verifying     2.4KB/  2.4KB]
# ✔︎ Formula graphite2 (1.3.14)                       [Verifying     6.6MB/  6.6MB]
# ✔︎ API Source icu4c@78.rb                           [Verifying     2.2KB/  2.2KB]
# ✔︎ Formula icu4c@78 (78.1)                          [Verifying    28.0MB/ 28.0MB]
# ✔︎ API Source gobject-introspection.rb              [Verifying     6.0KB/  6.0KB]
# ✔︎ Resource gobject-introspection--mako             [Verifying   392.5KB/392.5KB]
# ✔︎ Resource gobject-introspection--markdown         [Verifying   364.6KB/364.6KB]
# ✔︎ Resource gobject-introspection--markupsafe       [Verifying    20.5KB/ 20.5KB]
# ✔︎ Resource gobject-introspection--setuptools       [Verifying     1.3MB/  1.3MB]
# ✔︎ Formula gobject-introspection (1.86.0)           [Verifying     1.1MB/  1.1MB]
# ✔︎ API Source harfbuzz.rb                           [Verifying     2.4KB/  2.4KB]
# ✔︎ Formula harfbuzz (12.2.0)                        [Verifying    35.5MB/ 35.5MB]
# ✔︎ Bottle Manifest giflib (5.2.2)                   [Downloaded   10.8KB/ 10.8KB]
# ✔︎ Bottle giflib (5.2.2)                            [Downloaded  152.7KB/152.7KB]
# ✔︎ Bottle Manifest jpeg-turbo (3.1.2)               [Downloaded   10.7KB/ 10.7KB]
# ✔︎ Bottle jpeg-turbo (3.1.2)                        [Downloaded    1.1MB/  1.1MB]
# ✔︎ API Source libtiff.rb                            [Verifying     2.3KB/  2.3KB]
# ✔︎ Formula libtiff (4.7.1)                          [Verifying     4.0MB/  4.0MB]
# ✔︎ Bottle Manifest little-cms2 (2.17)               [Downloaded   15.1KB/ 15.1KB]
# ✔︎ Bottle little-cms2 (2.17)                        [Downloaded  433.3KB/433.3KB]
# ✔︎ API Source doxygen.rb                            [Verifying     2.0KB/  2.0KB]
# ✔︎ Formula doxygen (1.15.0)                         [Verifying     9.2MB/  9.2MB]
# ✔︎ API Source openjpeg.rb                           [Verifying     2.0KB/  2.0KB]
# ✔︎ Formula openjpeg (2.5.4)                         [Verifying     2.2MB/  2.2MB]
# ✔︎ Bottle Manifest webp (1.6.0)                     [Downloaded   19.5KB/ 19.5KB]
# ✔︎ Bottle webp (1.6.0)                              [Downloaded  909.8KB/909.8KB]
# ✔︎ API Source leptonica.rb                          [Verifying     1.9KB/  1.9KB]
# ✔︎ Formula leptonica (1.86.0)                       [Verifying    14.8MB/ 14.8MB]
# ✔︎ Bottle Manifest libb2 (0.98.1)                   [Downloaded   15.3KB/ 15.3KB]
# ✔︎ Bottle libb2 (0.98.1)                            [Downloaded   31.1KB/ 31.1KB]
# ✔︎ API Source libarchive.rb                         [Verifying     2.3KB/  2.3KB]
# ✔︎ Formula libarchive (3.8.2)                       [Verifying     5.9MB/  5.9MB]
# ✔︎ Bottle Manifest fribidi (1.0.16)                 [Downloaded   10.0KB/ 10.0KB]
# ✔︎ Bottle fribidi (1.0.16)                          [Downloaded   98.4KB/ 98.4KB]
# ✔︎ API Source pango.rb                              [Verifying     2.9KB/  2.9KB]
# ✔︎ Patch 4403954455f2b4a815b32e11c44f79b2e665e94c.d [Verifying   879.0 B/879.0 B]
# ✔︎ Formula pango (1.57.0)                           [Verifying     2.6MB/  2.6MB]
# ✔︎ Bottle Manifest m4 (1.4.20)                      [Downloaded   11.7KB/ 11.7KB]
# ✔︎ Bottle m4 (1.4.20)                               [Downloaded  279.5KB/279.5KB]
# ✔︎ Bottle Manifest autoconf (2.72)                  [Downloaded   19.7KB/ 19.7KB]
# ✔︎ Bottle autoconf (2.72)                           [Downloaded    1.1MB/  1.1MB]
# ✔︎ Bottle Manifest automake (1.18.1)                [Downloaded   18.2KB/ 18.2KB]
# ✔︎ Bottle automake (1.18.1)                         [Downloaded    1.1MB/  1.1MB]
# ✔︎ Bottle Manifest libtool (2.5.4)                  [Downloaded   13.8KB/ 13.8KB]
# ✔︎ Bottle libtool (2.5.4)                           [Downloaded    1.1MB/  1.1MB]
# ✔︎ Resource tesseract--eng                          [Verifying     4.1MB/  4.1MB]
# ✔︎ Resource tesseract--osd                          [Verifying    10.6MB/ 10.6MB]
# ⠙ Resource python@3.14--pip                        [Downloading   1.8MB/-------]
# ⠙ Resource tesseract--snum                         [Downloading   7.4MB/  8.5MB]
# ⠙ Formula tesseract (5.5.1)⠙ Resource python@3.14--pip                        [Downloading   1.8MB/-------]
# ⠙ Resource tesseract--snum                         [Verifying     8.5MB/  8.5MB]
# ⠙ Formula tesseract (5.5.1)✔︎ Resource tesseract--snum                         [Verifying     8.5MB/  8.5MB]
# ⠚ Resource python@3.14--pip                        [Downloading   1.8MB/-------]
# ⠚ Formula tesseract (5.5.1)⠚ Resource python@3.14--pip                        [Downloading   1.8MB/-------]
# ⠚ Formula tesseract (5.5.1)                        [Downloading 200.7KB/  0.0 B]⠞ Resource python@3.14--pip                        [Downloading   1.8MB/-------]
# ⠞ Formula tesseract (5.5.1)                        [Downloading   1.1MB/  0.0 B]⠞ Resource python@3.14--pip                        [Downloading   1.8MB/-------]
# ⠞ Formula tesseract (5.5.1)                        [Downloading   1.9MB/  0.0 B]✔︎ Formula tesseract (5.5.1)                        [Verifying     1.9MB/  1.9MB]
# ⠖ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠖ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠦ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠦ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠴ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠴ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠲ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠲ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠳ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠳ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠓ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠓ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠋ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠋ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠙ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠙ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠚ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠚ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠞ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠞ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠖ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠖ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠦ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠦ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠴ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠴ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠲ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠲ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠳ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠳ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠓ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠓ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠋ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠋ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠙ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠙ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠚ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠚ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠞ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠞ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠖ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠖ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠦ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠦ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠴ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠴ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠲ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠲ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠳ Resource python@3.14--pip                        [Downloading   1.8MB/-------]⠳ Resource python@3.14--pip                        [Downloading   1.8MB/-------] ...
# Warning: A newer Command Line Tools release is available.
# Update them from Software Update in System Settings.
#
# If that doesn't show you any updates, run:
#   sudo rm -rf /Library/Developer/CommandLineTools
#   sudo xcode-select --install
#
# Alternatively, manually download them from:
#   https://developer.apple.com/download/all/.
# You should download the Command Line Tools for Xcode 15.2.
#
#
#
# This is a Tier 2 configuration:
#   https://docs.brew.sh/Support-Tiers#tier-2
# You can report Tier 2 unrelated issues to Homebrew/* repositories!
# Read the above document before opening any issues or PRs.
#
# ==> Installing dependencies for tesseract: m4, autoconf, automake, libtool, libunistring, gettext, fontconfig, pcre2, bison, ninja, mpdecimal, ca-certificates, openssl@3, readline, sqlite, xz, lz4, zstd, expat, python@3.14, meson, python-setuptools, glib, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, lzo, pixman, cairo, graphite2, icu4c@78, gobject-introspection, harfbuzz, giflib, jpeg-turbo, libtiff, little-cms2, doxygen, openjpeg, webp, leptonica, libb2, libarchive, fribidi and pango
# ==> Installing tesseract dependency: m4
# ==> Pouring m4--1.4.20.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/m4/1.4.20: 14 files, 801.5KB
# ==> Installing tesseract dependency: autoconf
# ==> Pouring autoconf--2.72.arm64_ventura.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/autoconf/2.72: 72 files, 3.8MB
# ==> Installing tesseract dependency: automake
# ==> Pouring automake--1.18.1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/automake/1.18.1: 134 files, 3.6MB
# ==> Installing tesseract dependency: libtool
# ==> Pouring libtool--2.5.4.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libtool/2.5.4: 76 files, 4.1MB
# ==> Installing tesseract dependency: libunistring
# Warning: A newer Command Line Tools release is available.
# Update them from Software Update in System Settings.
#
# If that doesn't show you any updates, run:
#   sudo rm -rf /Library/Developer/CommandLineTools
#   sudo xcode-select --install
#
# Alternatively, manually download them from:
#   https://developer.apple.com/download/all/.
# You should download the Command Line Tools for Xcode 15.2.
#
#
#
# This is a Tier 2 configuration:
#   https://docs.brew.sh/Support-Tiers#tier-2
# You can report Tier 2 unrelated issues to Homebrew/* repositories!
# Read the above document before opening any issues or PRs.
#
# ==> ./configure --disable-silent-rules
# ==> make
# ==> make check
# ==> make install
# 🍺  /opt/homebrew/Cellar/libunistring/1.4.1: 59 files, 5.8MB, built in 6 minutes 2 seconds
# ==> Installing tesseract dependency: gettext
# Warning: A newer Command Line Tools release is available.
# Update them from Software Update in System Settings.
#
# If that doesn't show you any updates, run:
#   sudo rm -rf /Library/Developer/CommandLineTools
#   sudo xcode-select --install
#
# Alternatively, manually download them from:
#   https://developer.apple.com/download/all/.
# You should download the Command Line Tools for Xcode 15.2.
#
#
#
# This is a Tier 2 configuration:
#   https://docs.brew.sh/Support-Tiers#tier-2
# You can report Tier 2 unrelated issues to Homebrew/* repositories!
# Read the above document before opening any issues or PRs.
#
# ==> ./configure --with-libunistring-prefix=/opt/homebrew/opt/libunistring --disa
# ==> make
# ==> make install
# 🍺  /opt/homebrew/Cellar/gettext/0.26_1: 2,428 files, 29.3MB, built in 5 minutes 38 seconds
# ==> Installing tesseract dependency: fontconfig
# ==> Pouring fontconfig--2.17.1.arm64_ventura.bottle.1.tar.gz
# ==> Regenerating font cache, this may take a while
# ==> /opt/homebrew/Cellar/fontconfig/2.17.1/bin/fc-cache --force --really-force -
# 🍺  /opt/homebrew/Cellar/fontconfig/2.17.1: 98 files, 1.6MB
# ==> Installing tesseract dependency: pcre2
# Warning: A newer Command Line Tools release is available.
# Update them from Software Update in System Settings.
#
# If that doesn't show you any updates, run:
#   sudo rm -rf /Library/Developer/CommandLineTools
#   sudo xcode-select --install
#
# Alternatively, manually download them from:
#   https://developer.apple.com/download/all/.
# You should download the Command Line Tools for Xcode 15.2.
#
#
#
# This is a Tier 2 configuration:
#   https://docs.brew.sh/Support-Tiers#tier-2
# You can report Tier 2 unrelated issues to Homebrew/* repositories!
# Read the above document before opening any issues or PRs.
#
# ==> ./configure --enable-pcre2-16 --enable-pcre2-32 --enable-pcre2grep-libz --en
# ==> make
# ==> make install
# 🍺  /opt/homebrew/Cellar/pcre2/10.47: 244 files, 7.2MB, built in 19 seconds
# ==> Installing tesseract dependency: bison
# ==> Pouring bison--3.8.2.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/bison/3.8.2: 100 files, 3.9MB
# ==> Installing tesseract dependency: ninja
# ==> Pouring ninja--1.13.1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/ninja/1.13.1: 10 files, 449.4KB
# ==> Installing tesseract dependency: mpdecimal
# ==> Pouring mpdecimal--4.0.1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/mpdecimal/4.0.1: 22 files, 656.5KB
# ==> Installing tesseract dependency: ca-certificates
# ==> Pouring ca-certificates--2025-11-04.all.bottle.1.tar.gz
# ==> Regenerating CA certificate bundle from keychain, this may take a while...
# 🍺  /opt/homebrew/Cellar/ca-certificates/2025-11-04: 4 files, 241.5KB
# ==> Installing tesseract dependency: openssl@3
# Warning: A newer Command Line Tools release is available.
# Update them from Software Update in System Settings.
#
# If that doesn't show you any updates, run:
#   sudo rm -rf /Library/Developer/CommandLineTools
#   sudo xcode-select --install
#
# Alternatively, manually download them from:
#   https://developer.apple.com/download/all/.
# You should download the Command Line Tools for Xcode 15.2.
#
#
#
# This is a Tier 2 configuration:
#   https://docs.brew.sh/Support-Tiers#tier-2
# You can report Tier 2 unrelated issues to Homebrew/* repositories!
# Read the above document before opening any issues or PRs.
#
# ==> perl ./Configure --prefix=/opt/homebrew/Cellar/openssl@3/3.6.0 --openssldir=
# ==> make
# ==> make install MANDIR=/opt/homebrew/Cellar/openssl@3/3.6.0/share/man MANSUFFIX
# ==> make HARNESS_JOBS=8 test TESTS=-test_afalg
# Warning: The post-install step did not complete successfully
# You can try again using:
#   brew postinstall openssl@3
# ==> Summary
# 🍺  /opt/homebrew/Cellar/openssl@3/3.6.0: 7,600 files, 37.5MB, built in 3 minutes 36 seconds
# ==> Installing tesseract dependency: readline
# ==> Pouring readline--8.3.1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/readline/8.3.1: 56 files, 2.7MB
# ==> Installing tesseract dependency: sqlite
# xcrun: error: active developer path ("/Library/Developer/CommandLineTools") does not exist
# Use `sudo xcode-select --switch path/to/Xcode.app` to specify the Xcode that you wish to use for command line developer tools, or use `xcode-select --install` to install the standalone command line developer tools.
# See `man xcode-select` for more details.
# Error: An exception occurred within a child process:
#   CompilerSelectionError: sqlite cannot be built with any available compilers.
# Install GNU's GCC:
#   brew install gcc

# %%
## import libaries
import pandas as pd
import regex as re
import glob
from mangoCR import pdf2image_ocr_text
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[20], line 5
#       3 import regex as re
#       4 import glob
# ----> 5 from mangoCR import pdf2image_ocr_text
#
# File /opt/anaconda3/lib/python3.12/site-packages/mangoCR/__init__.py:1
# ----> 1 from .ocr_extractor import pdf2image_ocr, pdf2image_ocr_text
#
# File /opt/anaconda3/lib/python3.12/site-packages/mangoCR/ocr_extractor.py:6
#       4 # Check if Tesseract is installed
#       5 if not shutil.which("tesseract"):
# ----> 6     raise EnvironmentError("Tesseract is not installed or not found in PATH. Please install it following the instructions in the README.")
#       9 import fitz  # PyMuPDF
#      10 import pytesseract
#
# OSError: Tesseract is not installed or not found in PATH. Please install it following the instructions in the README.

# %%
## glob some pdfs together
target_pdfs = glob.glob("md-excerpts/*pdf")
target_pdfs

# %% [markdown]
# ### Single file analysis
#
# Let's see how it works on a single file before we iterate through all of them.

# %%
## convert pdf to text (not markdown)
text = pdf2image_ocr_text(target_pdfs[0])
text

# %% [markdown]
# ### Keyword Context Finder
#
# https://pypi.org/project/fuzzy-context-finder/

# %%
pip install pandas rapidfuzz
# Out:
# DEPRECATION: Loading egg at /opt/anaconda3/lib/python3.12/site-packages/dlib-20.0.99-py3.12-macosx-11.1-arm64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.3.3)
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.14.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading rapidfuzz-3.14.3-cp312-cp312-macosx_11_0_arm64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 2.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.14.3
# Note: you may need to restart the kernel to use updated packages.

# %%
## import the package
from fuzzy_context_finder import keyword_context_finder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 2
#       1 ## import the package
# ----> 2 from fuzzy_context_finder import keyword_context_finder
#
# ModuleNotFoundError: No module named 'fuzzy_context_finder'

# %%
keywords
# Out:
# ['opioid',
#  'prescription',
#  'sexual',
#  'abuse',
#  'assault',
#  'unlawful',
#  'fraud',
#  'controlled substances']

# %%
## create df
keyword_context_finder(text, keywords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 ## create df
# ----> 2 keyword_context_finder()
#
# NameError: name 'keyword_context_finder' is not defined

# %% [markdown]
# ## Hard to read text?
#
# We'll tap a package called <a href="https://pypi.org/project/tabular-2-text/">tabular_2_text</a>.

# %%
## import package

# %%
## convert to text

# %% [markdown]
# ## Now iterate through all files

# %%
## iterate through files

# %%
## how long is df_list?

# %%
## concat them

# %%
## get info

# %%
## convert to text
